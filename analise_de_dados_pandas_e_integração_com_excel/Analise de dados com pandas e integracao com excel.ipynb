# %% [markdown]
# # O que é o Pandas e para que serve
# - Análise de Dados (seja para DataScience, seja para trabalhar de forma integra com arquivos em Excel e Banco de Dados)
# - Melhor lib/modulo para trabalhar com grandes quantidades de informação
# - Uma mistura de listas e dicionários de forma muito eficiente

# %% [markdown]
# ## Resumo
# Se você trabalha com muitos dados, vai precisar usar o pandas

# %% [markdown]
# ## Forma de usar

# %%
import pandas as pd

# %% [markdown]
# # Padas e csv
# ## Resumo
# Quase sempre quando formos ler um arquivo csv, vamos usar o pandas. É pratico e bem eficiente.

# %% [markdown]
# ## Funcionamento
# `
# Forma mais básica: (muitas vezes não usaremos a forma mais básica)
# dataframe = pr.read_cdv(arquivo_com_extensao)
# `

# %% [markdown]
# - Vamos ler um arquivo real, com Base de Dados de Vendas da Empresa Contoso

# %%
vendas_df = pd.read_csv(r'arquivos/Contoso - Vendas - 2017.csv', sep=';')
print(vendas_df)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    01/01/2017    02/01/2017         1       86
# 1                     2    01/01/2017    06/01/2017         5      308
# 2                     3    01/01/2017    01/01/2017         0      294
# 3                     4    01/01/2017    01/01/2017         0      251
# 4                     5    01/01/2017    07/01/2017         6       94
# ...                 ...           ...           ...       ...      ...
# 980637           980638    31/12/2017    31/12/2017         0      194
# 980638           980639    31/12/2017    06/01/2018         6       32
# 980639           980640    31/12/2017    03/01/2018         3      210
# 980640           980641    31/12/2017    31/12/2017         0       53
# 980641           980642    31/12/2017    31/12/2017         0      309
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %%
vendas_df
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    01/01/2017    02/01/2017         1       86
# 1                     2    01/01/2017    06/01/2017         5      308
# 2                     3    01/01/2017    01/01/2017         0      294
# 3                     4    01/01/2017    01/01/2017         0      251
# 4                     5    01/01/2017    07/01/2017         6       94
# ...                 ...           ...           ...       ...      ...
# 980637           980638    31/12/2017    31/12/2017         0      194
# 980638           980639    31/12/2017    06/01/2018         6       32
# 980639           980640    31/12/2017    03/01/2018         3      210
# 980640           980641    31/12/2017    31/12/2017         0       53
# 980641           980642    31/12/2017    31/12/2017         0      309
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %% [markdown]
# # DataFrame
# ## Resumo
# É como se fosse uma tabela<br>
# - As colunas funcionam como chaves de dicionario
# - As linhas funcionam como listas

# %% [markdown]
# ## Funcionamento
# temos um dataframe chamado vendas_df
# ```
# vendas_df['coluna_x'] -> uma lista com valores da coluna_x (em formato dataframe, é um dataframe com uma coluna só)
# vendas_df[0] -> pega a primeira linha do dataframe
# vendas_df[:3] -> pega até a linha de indice 3 do dataframe
# vendas_df[[conluna_x, coluna_y, coluna_z]] -> cria um novo dataframe com as colunas conluna_x, coluna_y e coluna_z
# vendas_df[coluna_x][0] -> pega o item da primeira linha da coluna_x
# ```
# - Vamos ler um arquivo real, com Base de Dados de Vendas da Empresa Contoso

# %%
import pandas as pd
vendas_df = pd.read_csv('arquivos/Contoso - Vendas - 2017.csv', sep=';')
vendas_df['ID Cliente']
# Out:
# 0          6825
# 1         18469
# 2         19730
# 3         29326
# 4         22617
#           ...
# 980637    10353
# 980638    31750
# 980639    12003
# 980640    25550
# 980641    28707
# Name: ID Cliente, Length: 980642, dtype: int64

# %% [markdown]
# ## Aplicação
# - O primeiro passo de toda Análise de Dados é você entender o que existe na sua base de dados

# %% [markdown]
# Usaremos o .info() para isso

# %%
vendas_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980642 entries, 0 to 980641
# Data columns (total 10 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Numero da Venda       980642 non-null  int64
#  1   Data da Venda         980642 non-null  object
#  2   Data do Envio         980642 non-null  object
#  3   ID Canal              980642 non-null  int64
#  4   ID Loja               980642 non-null  int64
#  5   ID Produto            980642 non-null  int64
#  6   ID Promocao           980642 non-null  int64
#  7   ID Cliente            980642 non-null  int64
#  8   Quantidade Vendida    980642 non-null  int64
#  9   Quantidade Devolvida  980642 non-null  int64
# dtypes: int64(8), object(2)
# memory usage: 74.8+ MB

# %% [markdown]
# - Vamos criar então agora uma lista de Clientes

# %%
lista_clientes = vendas_df['ID Cliente']
lista_clientes
# Out:
# 0          6825
# 1         18469
# 2         19730
# 3         29326
# 4         22617
#           ...
# 980637    10353
# 980638    31750
# 980639    12003
# 980640    25550
# 980641    28707
# Name: ID Cliente, Length: 980642, dtype: int64

# %% [markdown]
# - Vamos criar agora uma lista com os produtos e as quantidades de vendas, caso a gente queira analisar só os produtos (independente do cliente)

# %%
produtos_quantidades = vendas_df[['ID Produto', 'Quantidade Vendida', 'Quantidade Devolvida']]
produtos_quantidades
# Out:
#         ID Produto  Quantidade Vendida  Quantidade Devolvida
# 0              981                   9                     1
# 1             1586                   9                     1
# 2             1444                  13                     1
# 3             1468                   6                     1
# 4             1106                   4                     1
# ...            ...                 ...                   ...
# 980637        2490                 120                     0
# 980638        2488                 120                     0
# 980639        2511                  80                     0
# 980640         436                  39                     0
# 980641        2510                  80                     0
#
# [980642 rows x 3 columns]

# %% [markdown]
# # Comparando, Tratando e Mesclando DataFrames
# ## Objetivo
# Vamos modificar os IDs para os nomes dos produtos, dos clientes e das lojas, para nossas análises ficarem mais intuitivas futuramente. Para isso, vamos criar uma data frame com todos os detalhes.
# - Usaremos o método merge para isso e, depois se quisermos, podemos pegar apenas as colunas que queremos do dataframe final.

# %% [markdown]
# ## Criando nossos dataframes

# %%
import pandas as pd

vendas_df = pd.read_csv(r'arquivos/Contoso - Vendas - 2017.csv', sep=';')
produtos_df = pd.read_csv(r'arquivos/Contoso - Cadastro Produtos.csv', sep=';')
lojas_df = pd.read_csv(r'arquivos/Contoso - Lojas.csv', sep=';')
clientes_df = pd.read_csv(r'arquivos/Contoso - Clientes.csv', sep=';')

display(vendas_df)
display(produtos_df)
display(lojas_df)
display(clientes_df)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    01/01/2017    02/01/2017         1       86
# 1                     2    01/01/2017    06/01/2017         5      308
# 2                     3    01/01/2017    01/01/2017         0      294
# 3                     4    01/01/2017    01/01/2017         0      251
# 4                     5    01/01/2017    07/01/2017         6       94
# ...                 ...           ...           ...       ...      ...
# 980637           980638    31/12/2017    31/12/2017         0      194
# 980638           980639    31/12/2017    06/01/2018         6       32
# 980639           980640    31/12/2017    03/01/2018         3      210
# 980640           980641    31/12/2017    31/12/2017         0       53
# 980641           980642    31/12/2017    31/12/2017         0      309
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %% [markdown]
# ## Vamos tirar as colunas inúteis do clientes_df ou pegar apenas as colunas que quisermos

# %% [markdown]
# ```
# .drop([coluna1, coluna2, coluna3]) -> retira as colunas: coluna1, coluna2 e coluna3
# ```

# %%
# axis 1 = coluna
# axis 0 = linha
# retirar colunas
clientes_df = clientes_df.drop(['Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10'], axis=1)
display(clientes_df)
# Out:
#        ID Cliente Primeiro Nome     Sobrenome                         E-mail  \
# 0               1        Garnet    Lanfranchi    glanfranchi0@mayoclinic.com
# 1               2       Lurette     Roseblade      lroseblade1@bigcartel.com
# 2               3       Glenden     Ishchenko      gishchenko2@moonfruit.com
# 3               4         Baron  Jedrzejewsky    bjedrzejewsky3@e-recht24.de
# 4               5        Sheree      Bredbury       sbredbury4@sitemeter.com
# ...           ...           ...           ...                            ...
# 39499       39500        Brandy      Malhotra    brandy0@adventure-works.com
# 39500       39501        Alicia          Raje   alicia12@adventure-works.com
# 39501       39502        Connie           Rai    connie4@adventure-works.com
# 39502       39503         Shawn          Raji    shawn23@adventure-works.com
# 39503       39504       Lindsey        Sharma  lindsey10@adventure-works.com
#
# ...

# %%
# deixar somente as colunas
clientes_df = clientes_df[['ID Cliente', 'E-mail']]
produtos_df = produtos_df[['ID Produto', 'Nome da Marca']]
lojas_df = lojas_df[['ID Loja', 'Nome da Loja']]
display(produtos_df)
# Out:
#       ID Produto     Nome da Marca
# 0            873           Contoso
# 1            879           Contoso
# 2            880           Contoso
# 3            881           Contoso
# 4            882           Contoso
# ...          ...               ...
# 1685        1602  Southridge Video
# 1686        1606  Southridge Video
# 1687        1607  Southridge Video
# 1688        1611  Southridge Video
# 1689        1612  Southridge Video
#
# [1690 rows x 2 columns]

# %% [markdown]
# ## Agora vamos juntar dataframes para ter um unico dataframe com tudo

# %% [markdown]
# ``
# novo_dataframe = dataframe1.merge(dataframe2, on='coluna')
# ``

# %% [markdown]
# - Obs: O merge precisa das colunas com o mesmo nome para funcionar. Se não tiver, você precisa alterar o nome da coluna com .rename

# %% [markdown]
# ``
# dataframe.rename(columns={'coluna1': 'nova_coluna1'})
# ``

# %%
# juntando dataframes
vendas_df = vendas_df.merge(produtos_df, on='ID Produto')
vendas_df = vendas_df.merge(lojas_df, on='ID Loja')
vendas_df = vendas_df.merge(clientes_df, on='ID Cliente')


display(vendas_df)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    01/01/2017    02/01/2017         1       86
# 1                880458    23/11/2017    23/11/2017         0      306
# 2                191019    20/03/2017    21/03/2017         1      172
# 3                 18610    08/01/2017    10/01/2017         2      200
# 4                287704    23/04/2017    26/04/2017         3       76
# ...                 ...           ...           ...       ...      ...
# 980637           853643    13/11/2017    20/11/2017         7      115
# 980638           903958    02/12/2017    02/12/2017         0      222
# 980639           685591    16/09/2017    20/09/2017         4      132
# 980640           931644    13/12/2017    14/12/2017         1      132
# 980641           881300    24/11/2017    24/11/2017         0      132
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %%
vendas_df = vendas_df.rename(columns={'E-mail': 'E-mail Cliente'})
display(vendas_df)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    01/01/2017    02/01/2017         1       86
# 1                880458    23/11/2017    23/11/2017         0      306
# 2                191019    20/03/2017    21/03/2017         1      172
# 3                 18610    08/01/2017    10/01/2017         2      200
# 4                287704    23/04/2017    26/04/2017         3       76
# ...                 ...           ...           ...       ...      ...
# 980637           853643    13/11/2017    20/11/2017         7      115
# 980638           903958    02/12/2017    02/12/2017         0      222
# 980639           685591    16/09/2017    20/09/2017         4      132
# 980640           931644    13/12/2017    14/12/2017         1      132
# 980641           881300    24/11/2017    24/11/2017         0      132
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...
